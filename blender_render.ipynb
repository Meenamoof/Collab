# %% [markdown]
# # Setup
# **Make sure to read the instructions carefully!**
#
# If you have other resources used in the Blender project and chose to *make all paths relative*, pack all of them into a zip archive. Alternatively, you can *pack all external file*.
#
# * `blender_version` : Version of blender used to render the scene. You may define your own blender version.
# * `blend_file_path` : Path to the blend file after unpacking the zip archive. If blend file is used, this is automatically ignored.
# ___
# * `upload_type` : Select the type of upload method. `gdrive_relative` pulls everything from the folder specified.
# * `drive_path` : Path to your blend/zip file relative to the root of your Google Drive if `google_drive` is selected. Must  state the file and its extension (.zip/.blend) **unless** `gdrive_relative` is selected.
# * `url_blend` : Specify the URL to the blend/zip file if `url` is selected.
# ___
# * `animation` : Specify whether animation or still image is rendered. If **still image** is used, put the frame number in `start_frame`.
# * `start_frame, end_frame` : Specify the start and end frame for animation. You may put same value such as zero for both input to set the default frame in the blend file.
# ___
# * `download_type` : Select the type of download method. `gdrive_direct` enables the frames to be outputted directly to Google Drive (zipping will be disabled).
# * `output_name` : Name of the output frames, **do NOT include .blend!** (## for frame number)
# * `zip_files` : Archive multiple animation frames automatically into a zip file.
# * `drive_output_path` : Path to your frames/zip file in Google Drive.
# ___
# * `gpu_enabled, cpu_enabled` : Toggle GPU and CPU for rendering. CPU might give a slight boost in rendering time but may varies depend on the project.
# * `optix_enable` : Enable OptiX which may boost performance, may be incompatible depending on the version of blender, project and GPU allocated
#
# After you are done, go to Runtime > Run All (Ctrl + F9) and upload your files or have Google Drive authorised below. See the [GitHub repo](https://github.com/syn73/blender-colab) for more information.

# %%
blender_version = '4.5.2' #@param ['4.5.2', '2.79b', '2.83.20', '2.93.18', '3.3.21', '3.6.23', '4.2.12', '4.5.1'] {allow-input: true}
blend_file_path = 'path/to/file.blend' #@param {type: 'string'}
#@markdown ---
upload_type = 'google_drive' #@param ['direct', 'google_drive', 'url', 'gdrive_relative'] {allow-input: false}
drive_path = 'lara.blend' #@param {type: 'string'}
url_blend = 'https://drive.google.com/file/d/1XsBDfTCssu5wMgFNNAWFaZun-Yop1fp2/view?usp=drive_link' #@param {type: 'string'}
#@markdown ---
animation = True #@param {type: 'boolean'}
start_frame =  1#@param {type: 'integer'}
end_frame =  60#@param {type: 'integer'}
#@markdown ---
download_type = 'gdrive_direct' #@param ['direct', 'google_drive', 'gdrive_direct'] {allow-input: false}
output_name = 'blender-##' #@param {type: 'string'}
zip_files = True #@param {type: 'boolean'}
drive_output_path = 'output' #@param {type: 'string'}
#@markdown ---
gpu_enabled = True #@param {type:"boolean"}
optix_enabled = False #@param {type:"boolean"}
cpu_enabled = False #@param {type:"boolean"}

# %%
# %cd /content

gpu = !nvidia-smi --query-gpu=gpu_name --format=csv,noheader
print("Current GPU: " + gpu[0])

if gpu[0] == "Tesla K80" and optix_enabled:
  print("OptiX disabled because of unsupported GPU")
  optix_enabled = False
# Out:
# /content
# Current GPU: Tesla T4

# %%
import os

os.environ["LD_PRELOAD"] = ""

# !apt remove libtcmalloc-minimal4
# !apt install libtcmalloc-minimal4

os.environ["LD_PRELOAD"] = "/usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4.5.9"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages will be REMOVED:
#   google-perftools libgoogle-perftools4 libtcmalloc-minimal4
# 0 upgraded, 0 newly installed, 3 to remove and 35 not upgraded.
# After this operation, 1,817 kB disk space will be freed.
# (Reading database ... 126374 files and directories currently installed.)
# Removing google-perftools (2.9.1-0ubuntu3) ...
# Removing libgoogle-perftools4:amd64 (2.9.1-0ubuntu3) ...
# Removing libtcmalloc-minimal4:amd64 (2.9.1-0ubuntu3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libtcmalloc-minimal4
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 98.2 kB of archives.
# After this operation, 382 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtcmalloc-minimal4 amd64 2.9.1-0ubuntu3 [98.2 kB]
# Fetched 98.2 kB in 2s (41.7 kB/s)
# Selecting previously unselected package libtcmalloc-minimal4:amd64.
# (Reading database ... 126349 files and directories currently installed.)
# Preparing to unpack .../libtcmalloc-minimal4_2.9.1-0ubuntu3_amd64.deb ...
# Unpacking libtcmalloc-minimal4:amd64 (2.9.1-0ubuntu3) ...
# Setting up libtcmalloc-minimal4:amd64 (2.9.1-0ubuntu3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link

# %%
import shutil
from google.colab import files, drive
uploaded_filename = ""

if upload_type == 'google_drive' or upload_type == 'gdrive_relative' or download_type == 'google_drive' or download_type == 'gdrive_direct':
    drive.mount('/drive')

if upload_type == 'direct':
    uploaded = files.upload()
    for fn in uploaded.keys():
        uploaded_filename = fn
elif upload_type == 'url':
    # !wget -nc $url_blend
    uploaded_filename = os.path.basename(url_blend)
elif upload_type == 'google_drive':
    shutil.copy('/drive/MyDrive/' + drive_path, '.')
    uploaded_filename = os.path.basename(drive_path)
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
# !rm -r render
# !mkdir render

if upload_type == 'gdrive_relative':
    if not drive_path.endswith('/'):
        drive_path += '/'
    # !cp -r '/drive/MyDrive/{drive_path}.' 'render/'
elif uploaded_filename.lower().endswith('.zip'):
    # !unzip -o $uploaded_filename -d 'render/'
elif uploaded_filename.lower().endswith('.blend'):
    shutil.copy(uploaded_filename, 'render/')
    blend_file_path = uploaded_filename
else:
    raise SystemExit("Invalid file extension, only .blend and .zip can be uploaded.")
# Out:
# rm: cannot remove 'render': No such file or directory

# %%
import requests
blender_url_dict = {
    '4.5.2'   : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender4.5/blender-4.5.2-linux-x64.tar.xz",
    '2.79b'   : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.79/blender-2.79b-linux-glibc219-x86_64.tar.bz2",
    '2.83.20' : "https://ftp.nluug.nl/pub/graphics/blender/release/Blender2.83/blender-2.83.20-linux-x64.tar.xz" # example
    # Add any custom Linux binaries here (You may refer to https://ftp.nluug.nl/pub/graphics/blender/release)
}

if blender_version in blender_url_dict:
    blender_url = blender_url_dict[blender_version]
else:
    major_minor = ".".join(blender_version.split('.')[:2])
    blender_url = f"https://ftp.nluug.nl/pub/graphics/blender/release/Blender{major_minor}/blender-{blender_version}-linux-x64.tar.xz"

try:
    response = requests.head(blender_url, allow_redirects=True, timeout=10)
    if response.status_code != 200:
        print(f"Download failed for version '{blender_version}'.")
        print("Error downloading: You may need to define the download archive manually above.")
    else:
        base_url = os.path.basename(blender_url)
        print(f"Download URL: {blender_url}")
        print(f"Base filename: {base_url}")
except Exception as e:
    print(f"Error checking URL: {e}")
    print("Error downloading: You may need to define the download archive manually above.")

# !mkdir $blender_version
# !wget -nc $blender_url
# !tar -xkf $base_url -C ./$blender_version --strip-components=1
# Out:
# Download URL: https://ftp.nluug.nl/pub/graphics/blender/release/Blender4.5/blender-4.5.2-linux-x64.tar.xz
# Base filename: blender-4.5.2-linux-x64.tar.xz
# --2025-09-06 11:27:46--  https://ftp.nluug.nl/pub/graphics/blender/release/Blender4.5/blender-4.5.2-linux-x64.tar.xz
# Resolving ftp.nluug.nl (ftp.nluug.nl)... 145.220.21.40, 2001:67c:6ec:221:145:220:21:40
# Connecting to ftp.nluug.nl (ftp.nluug.nl)|145.220.21.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 377398292 (360M) [application/octet-stream]
# Saving to: ‘blender-4.5.2-linux-x64.tar.xz’
#
# blender-4.5.2-linux 100%[===================>] 359.92M  24.5MB/s    in 15s
#
# 2025-09-06 11:28:03 (23.3 MB/s) - ‘blender-4.5.2-linux-x64.tar.xz’ saved [377398292/377398292]

# %%
# Enable GPU rendering (or add custom properties here)
data = "import re\n"+\
    "import bpy\n"+\
    "scene = bpy.context.scene\n"+\
    "scene.cycles.device = 'GPU'\n"+\
    "prefs = bpy.context.preferences\n"+\
    "prefs.addons['cycles'].preferences.get_devices()\n"+\
    "cprefs = prefs.addons['cycles'].preferences\n"+\
    "print(cprefs)\n"+\
    "for compute_device_type in ('CUDA', 'OPENCL', 'NONE'):\n"+\
    "    try:\n"+\
    "        cprefs.compute_device_type = compute_device_type\n"+\
    "        print('Device found:',compute_device_type)\n"+\
    "        break\n"+\
    "    except TypeError:\n"+\
    "        pass\n"+\
    "for device in cprefs.devices:\n"+\
    "    if not re.match('intel', device.name, re.I):\n"+\
    "        print('Activating',device)\n"+\
    "        device.use = "+str(gpu_enabled)+"\n"+\
    "    else:\n"+\
    "        device.use = "+str(cpu_enabled)+"\n"
with open('setgpu.py', 'w') as f:
    f.write(data)

renderer = "CUDA"
if optix_enabled:
    print("Note: You're currently using OptiX renderer. If an error occurred, the current GPU (e.g. Tesla K80) is not supported and you need to switch back to CUDA.")
    renderer = "OPTIX"

# %%
# %cd /content

# !rm -r output
# !mkdir output

if not drive_output_path.endswith('/'):
    drive_output_path += '/'

if download_type != 'gdrive_direct':
    output_path = '/content/output/' + output_name
else:
    output_path = '/drive/MyDrive/' + drive_output_path + output_name

# %cd /content/$blender_version

if animation:
    if start_frame == end_frame:
        # !./$blender_version/blender -b '/content/render/{blend_file_path}' -P "/content/setgpu.py" -E CYCLES -o '{output_path}' -noaudio -a -- --cycles-device "{renderer}"
    else:
        # !./$blender_version/blender -b '/content/render/{blend_file_path}' -P "/content/setgpu.py" -E CYCLES -o '{output_path}' -noaudio -s $start_frame -e $end_frame -a -- --cycles-device "{renderer}"
else:
    # !./$blender_version/blender -b '/content/render/{blend_file_path}' -P "/content/setgpu.py" -E CYCLES -o '{output_path}' -noaudio -f $start_frame -- --cycles-device "{renderer}"
# Out:
# /content
# rm: cannot remove 'output': No such file or directory
# /content/4.5.2
# Blender 4.5.2 LTS (hash ab25eae04993 built 2025-08-20 02:11:19)
# Read blend: "/content/render/lara.blend"
# scripts disabled for "/content/render/lara.blend", skipping 'daz_morphs.py'
# Dependency cycle detected:
#   OBLara Body/VISIBILITY() depends on
#   OBLara Body/DRIVER(modifiers["CorrectiveSmooth"].show_viewport) via 'Driver -> Driven Property'
#   OBLara Body/VISIBILITY() via 'RNA Target -> Driver'
# Dependency cycle detected:
#   OBLara Body/VISIBILITY() depends on
#   OBLara Body/DRIVER(modifiers["CorrectiveSmooth"].show_render) via 'Driver -> Driven Property'
#   OBLara Body/VISIBILITY() via 'RNA Target -> Driver'
# Detected 2 dependency cycles
# 	BPY_driver_exec: restricted access disallows opcode '132', enable auto-execution to support
#
# Error in PyDriver: expression failed: [1 if x< -1 else -1*x+0 if x< 0  else 0 for x in [+1.003487*A-0.009518*B-0.136254*C]][0]
# For target: (type=Key, name="Key.045", property=value, property_index=-1)
#
# 	BPY_driver_exec: restricted access disallows opcode '132', enable auto-execution to support
#
# Error in PyDriver: expression failed: [1 if x< -1 else -1*x+0 if x< 0  else 0 for x in [+1.003485*A+0.004698*B+0.143355*C]][0]
# For target: (type=Key, name="Key.045", property=value, property_index=-1)
#
# 	BPY_driver_exec: restricted access disallows opcode '132', enable auto-execution to support
#
# Error in PyDriver: expression failed: [1 if x< -1.982759 else -1*x-0.982759 if x< -0.982759  else 0 for x in [+0.986186*A-0.009354*B-0.133905*C]][0]
# For target: (type=Key, name="Key.045", property=value, property_index=-1)
#
# 	BPY_driver_exec: restricted access disallows opcode '132', enable auto-execution to support
#
# Error in PyDriver: expression failed: [1 if x< -1.982759 else -1*x-0.982759 if x< -0.982759  else 0 for x in [+0.986184*A+0.004617*B+0.140884*C]][0]
# For target: (type=Key, name="Key.045", property=value, property_index=-1)
#
# 	BPY_driver_exec: restricted access disallows opcode '132', enable auto-execution to support
#
# Error in PyDriver: expression failed: [0 if x< 1.384615 else 1*x-1.384615 if x< 2.384615  else 1 for x in [+0.874789*A-0.004831*B-0.245992*C]][0]
# For target: (type=Key, name="Key.045", property=value, property_index=-1)
#
# 	BPY_driver_exec: restricted access disallows opcode '132', enable auto-execution to support
#
# Error in PyDriver: expression failed: [0 if x< 1.384615 else 1*x-1.384615 if x< 2.384615  else 1 for x in [+0.874789*A+0.004126*B+0.245655*C]][0]
# For target: (type=Key, name="Key.045", property=value, property_index=-1)
#
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidLowerInner"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidLowerInner"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidLowerInner"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidLower"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidLower"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidLower"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidLowerOuter"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidLowerOuter"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidLowerOuter"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidOuter"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidOuter"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidUpperOuter"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidUpperOuter"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidUpperOuter"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidUpper"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidUpper"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidUpper"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidUpperInner"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidUpperInner"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidUpperInner"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidInner"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["rEyelidInner"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidLowerInner"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidLowerInner"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidLowerInner"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidLower"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidLower"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidLower"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidLowerOuter"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidLowerOuter"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidLowerOuter"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidOuter"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidOuter"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidUpperOuter"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidUpperOuter"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidUpperOuter"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidUpper"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidUpper"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidUpper"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidUpperInner"].rotation_euler[1]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidUpperInner"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidUpperInner"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidInner"].rotation_euler[2]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["lEyelidInner"].rotation_euler[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_pole_ik_socket.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-upper_arm_ik.R"].constraints["IK.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-upper_arm_ik.R"].constraints["IK"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_ik_socket.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_pole_ik_socket.R"].constraints["Copy Transforms.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_pole_ik_socket.R"].constraints["Copy Transforms"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_ik_socket.R"].constraints["Copy Transforms.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_ik_socket.R"].constraints["Copy Transforms"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-upper_arm_ik_stretch.R"].constraints["Limit Scale"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-hand.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-forearm.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-upper_arm.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-upper_arm_parent.R"].constraints["Copy Rotation"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_pole_ik_socket.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-upper_arm_ik.L"].constraints["IK.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-upper_arm_ik.L"].constraints["IK"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_ik_socket.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_pole_ik_socket.L"].constraints["Copy Transforms.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_pole_ik_socket.L"].constraints["Copy Transforms"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_ik_socket.L"].constraints["Copy Transforms.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-hand_ik_socket.L"].constraints["Copy Transforms"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-upper_arm_ik_stretch.L"].constraints["Limit Scale"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-hand.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-forearm.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-upper_arm.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-upper_arm_parent.L"].constraints["Copy Rotation"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_pole_ik_socket.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-thigh_ik.R"].constraints["IK.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-thigh_ik.R"].constraints["IK"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_ik_socket.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_pole_ik_socket.R"].constraints["Copy Transforms.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_pole_ik_socket.R"].constraints["Copy Transforms"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_ik_socket.R"].constraints["Copy Transforms.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_ik_socket.R"].constraints["Copy Transforms"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-toe.R"].constraints["Copy Transforms"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-thigh_ik_stretch.R"].constraints["Limit Scale"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-foot.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-shin.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-thigh.R"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-thigh_parent.R"].constraints["Copy Rotation"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_pole_ik_socket.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-thigh_ik.L"].constraints["IK.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-thigh_ik.L"].constraints["IK"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_ik_socket.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_pole_ik_socket.L"].constraints["Copy Transforms.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_pole_ik_socket.L"].constraints["Copy Transforms"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_ik_socket.L"].constraints["Copy Transforms.001"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-foot_ik_socket.L"].constraints["Copy Transforms"].mute[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-toe.L"].constraints["Copy Transforms"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-thigh_ik_stretch.L"].constraints["Limit Scale"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-foot.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-shin.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["ORG-thigh.L"].constraints["Copy Transforms.001"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-thigh_parent.L"].constraints["Copy Rotation"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-ROT-neck"].constraints["Copy Rotation"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - pose.bones["MCH-ROT-head"].constraints["Copy Rotation"].influence[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - nodes["Mix"].inputs[1].default_value[3]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - nodes["Mix"].inputs[1].default_value[3]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - nodes["Mix"].inputs[1].default_value[3]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - nodes["Mix"].inputs[1].default_value[3]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - nodes["Mix"].inputs[1].default_value[3]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - layers[17]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["VIS_upper_arm_ik_pole.R"].hide[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["upper_arm_ik_target.R"].hide[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-forearm.R.001"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-forearm.R"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-forearm.R"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-upper_arm.R.001"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-upper_arm.R.001"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-upper_arm.R"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["VIS_upper_arm_ik_pole.L"].hide[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["upper_arm_ik_target.L"].hide[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-forearm.L.001"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-forearm.L"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-forearm.L"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-upper_arm.L.001"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-upper_arm.L.001"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-upper_arm.L"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["VIS_thigh_ik_pole.R"].hide[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["thigh_ik_target.R"].hide[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-shin.R.001"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-shin.R"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-shin.R"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-thigh.R.001"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-thigh.R.001"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-thigh.R"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["VIS_thigh_ik_pole.L"].hide[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["thigh_ik_target.L"].hide[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-shin.L.001"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-shin.L"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-shin.L"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-thigh.L.001"].bbone_easeout[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-thigh.L.001"].bbone_easein[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - bones["DEF-thigh.L"].bbone_easeout[0]
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 1.0-(+evalMorphsRot0(self))
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=1)
#
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - child_nbr[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - child_nbr[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - child_nbr[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - child_nbr[0]
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=2)
#
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - child_nbr[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - child_nbr[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - child_nbr[0]
# WARN (bke.anim_sys): source/blender/blenkernel/intern/anim_sys.cc:4299 BKE_animsys_eval_driver: invalid driver - child_nbr[0]
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot3', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot3(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=3)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 1.0-(+evalMorphsRot0(self))
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot3', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot3(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=3)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 1.0-(+evalMorphsRot0(self))
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot3', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot3(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=3)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 1.0-(+evalMorphsRot0(self))
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot3', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot3(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=3)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 1.0-(+evalMorphsRot0(self))
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot3', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot3(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=3)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 1.0-(+evalMorphsRot0(self))
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot3', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot3(self)
# For target: (type=Object, name="Lara", property=rotation_quaternion, property_index=3)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc0(self)
# For target: (type=Object, name="Lara", property=location, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc1(self)
# For target: (type=Object, name="Lara", property=location, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc2(self)
# For target: (type=Object, name="Lara", property=location, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc0(self)
# For target: (type=Object, name="Lara", property=location, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc1(self)
# For target: (type=Object, name="Lara", property=location, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc2(self)
# For target: (type=Object, name="Lara", property=location, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc0(self)
# For target: (type=Object, name="Lara", property=location, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc1(self)
# For target: (type=Object, name="Lara", property=location, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc2(self)
# For target: (type=Object, name="Lara", property=location, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc0(self)
# For target: (type=Object, name="Lara", property=location, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc1(self)
# For target: (type=Object, name="Lara", property=location, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc2(self)
# For target: (type=Object, name="Lara", property=location, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc0(self)
# For target: (type=Object, name="Lara", property=location, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc1(self)
# For target: (type=Object, name="Lara", property=location, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc2(self)
# For target: (type=Object, name="Lara", property=location, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc0(self)
# For target: (type=Object, name="Lara", property=location, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc1(self)
# For target: (type=Object, name="Lara", property=location, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc2(self)
# For target: (type=Object, name="Lara", property=location, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc0(self)
# For target: (type=Object, name="Lara", property=location, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc1(self)
# For target: (type=Object, name="Lara", property=location, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc2(self)
# For target: (type=Object, name="Lara", property=location, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc0(self)
# For target: (type=Object, name="Lara", property=location, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc1(self)
# For target: (type=Object, name="Lara", property=location, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc2(self)
# For target: (type=Object, name="Lara", property=location, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc0(self)
# For target: (type=Object, name="Lara", property=location, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc1(self)
# For target: (type=Object, name="Lara", property=location, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsLoc2', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsLoc2(self)
# For target: (type=Object, name="Lara", property=location, property_index=2)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot0', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot0(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=0)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot1', enable auto-execution to support
#
# Error in PyDriver: expression failed: 0.0+evalMorphsRot1(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=1)
#
# 	BPY_driver_exec: restricted access disallows name 'evalMorphsRot2', enable auto-execution to support
#
# Error in PyDriver: expression failed: -0.0+evalMorphsRot2(self)
# For target: (type=Object, name="Lara", property=rotation_euler, property_index=2)
#
# ...
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:42.73 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 11%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:42.99 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 12%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:43.24 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 14%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:43.50 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 15%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:43.76 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 16%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:44.01 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 18%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:44.51 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 20%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:44.76 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 21%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:45.02 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 22%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:45.28 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 24%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:45.53 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 25%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:45.78 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 26%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:46.03 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 28%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:46.29 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 29%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:46.54 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 30%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:46.79 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 32%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:47.05 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 33%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:47.30 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 35%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:47.55 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 36%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:47.82 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 37%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:48.07 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 38%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:48.32 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 39%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:48.57 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 40%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:48.83 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 42%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:49.08 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 43%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:49.33 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 44%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:49.59 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 45%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:49.84 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 46%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:50.10 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 47%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:50.35 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 48%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:50.61 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 49%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:51.13 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 50%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:51.39 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 51%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:51.65 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 52%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:52.16 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 53%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:52.42 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 54%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:52.68 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 55%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:53.20 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 56%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:53.46 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 57%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:53.97 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 58%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:54.23 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 59%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:54.49 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 60%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:54.74 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 61%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:55.00 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 62%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:55.50 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 63%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:55.76 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 65%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:56.01 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 66%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:56.27 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 67%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:56.52 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 68%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:56.80 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 69%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:57.05 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 70%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:57.30 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 72%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:57.55 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 73%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:57.81 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 75%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:58.06 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 76%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:58.31 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 77%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:58.57 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 79%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:58.82 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 80%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:59.08 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 82%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:59.33 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 83%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:59.58 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 84%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:00:59.83 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 86%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:00.08 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 87%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:00.33 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 88%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:00.59 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 90%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:00.84 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 92%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:01.09 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 93%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:01.34 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 94%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:01.60 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 96%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:01.85 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 97%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:02.10 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Building BVH 99%, duplicates 0%
# Fra:6 Mem:5150.17M (Peak 9002.32M) | Time:01:02.48 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Packing BVH triangles and strands
# Fra:6 Mem:5198.13M (Peak 9002.32M) | Time:01:02.52 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Geometry BVH Group2.001 2/6 | Packing BVH nodes
# Fra:6 Mem:4906.83M (Peak 9002.32M) | Time:01:04.19 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Scene BVH | Building
# Fra:6 Mem:4906.83M (Peak 9002.32M) | Time:01:04.19 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Scene BVH | Building BVH
# Fra:6 Mem:4908.60M (Peak 9002.32M) | Time:01:04.23 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:6 Mem:4908.71M (Peak 9002.32M) | Time:01:04.23 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Scene BVH | Packing BVH nodes
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.72 | Mem:1312.83M, Peak:2509.32M | Scene, View Layer | Updating Scene BVH | Copying BVH to device
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.84 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Mesh | Computing normals
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.84 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Mesh | Copying Mesh to device
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.85 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Mesh | Copying Curves to device
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Objects Flags
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Primitive Offsets
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Images
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Camera Volume
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Lookup Tables
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Lights
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Lights | Computing distribution
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Integrator
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Film
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Lookup Tables
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Baking
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Updating Device | Writing constant memory
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:04.98 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Sample 0/128
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:06.22 | Remaining:02:37.61 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Sample 1/128
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:01:36.07 | Remaining:01:29.49 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Sample 33/128
# Fra:6 Mem:5900.10M (Peak 9002.32M) | Time:02:22.68 | Remaining:00:36.61 | Mem:1809.47M, Peak:2509.32M | Scene, View Layer | Sample 87/128

# %%
# %cd /content

path, dirs, files_folder = next(os.walk("output"))
output_folder_name = output_name.replace('#', '') + 'render'

if download_type == 'gdrive_direct':
    pass
elif len(files_folder) == 1:
    render_img = 'output/' + files_folder[0]
    if download_type == 'direct':
        files.download('output/' + files_folder[0])
    else:
        shutil.copy('/content/' + render_img, '/drive/MyDrive/' + drive_output_path)
elif len(files_folder) > 1:
    if zip_files:
        shutil.make_archive(output_folder_name, 'zip', 'output')
    if download_type == 'direct':
        files.download(output_folder_name + '.zip')
    else:
        shutil.copy('/content/' + output_folder_name + ".zip", '/drive/MyDrive/' + drive_output_path)
elif download_type == 'direct':
    for f in files_folder:
        files.download('output/{}'.format(f))
    # Drive, no zip
    else:
        for f in files_folder:
          shutil.copy("/content/output/" + f, '/drive/MyDrive/' + drive_output_path + f)
else:
    raise SystemExit("No frames are rendered.")
# Out:
# /content
